# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math

# %%
df=pd.read_csv("data.csv")
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
print(df.shape)
# Out:
# (50, 7)

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# 25%        2.587500e+05               1.000000
# 50%        4.474200e+05               1.000000
# 75%        5.947200e+05               2.000000
# max        1.404000e+06               4.000000

# %% [markdown]
# ### Defintion:- mean is the total of the sum of all values in a collection of numbers divided by the number of numbers in a collection.

# %%
df.mean()
# Out:
# Mthly_HH_Income              41558.00
# Mthly_HH_Expense             18818.00
# No_of_Fly_Members                4.06
# Emi_or_Rent_Amt               3060.00
# Annual_HH_Income            490019.04
# Highest_Qualified_Member         1.74
# No_of_Earning_Members            1.46
# dtype: float64

# %%
#without library function
for column in df.columns:
    df[column]=df[column].astype('float')
    sum=df[column].sum()
    count=df[column].count()
    print(f"{column}  {sum/count}")
# Out:
# Mthly_HH_Income  41558.0
# Mthly_HH_Expense  18818.0
# No_of_Fly_Members  4.06
# Emi_or_Rent_Amt  3060.0
# Annual_HH_Income  490019.04
# Highest_Qualified_Member  1.74
# No_of_Earning_Members  1.46

# %%
plt.figure(figsize=(20,20))
plt.title(f"Monthly income Histplot")
sns.barplot(df["Mthly_HH_Income"],df["Highest_Qualified_Member"])
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10, 10))
plt.title(f"Annual_HH_Income Level Distribution")
sns.histplot(df['Annual_HH_Income'], stat='density', color='grey')
sns.kdeplot(df['Annual_HH_Income'], color='red')
plt.axvline(df['Annual_HH_Income'].mean(), color='blue',linestyle="--")
plt.show()

# %% [markdown]
# ### First arrange the observation(n) in ascending order then:
# ### 1.If number of observation(n) is odd:- $$ \frac{(n+1)}{2}^{th} term $$
# ### 2.1.If number of observation(n) is even:-  $$\frac{n}{2}^{th} term + \frac{n}{2}+1^{th}$$

# %%
print(df.median())
# Out:
# Mthly_HH_Income              35000.0
# Mthly_HH_Expense             15500.0
# No_of_Fly_Members                4.0
# Emi_or_Rent_Amt                  0.0
# Annual_HH_Income            447420.0
# Highest_Qualified_Member         2.0
# No_of_Earning_Members            1.0
# dtype: float64

# %%
# without using library
for col in df.columns:
    l=list(df[col])
    l.sort()
    n=len(l)
    if n%2==0:
        med1=l[n//2]
        med2=l[n//2+1]
        med=(med1+med2)/2
        print(f"{col}   {med}")
# Out:
# Mthly_HH_Income   37000.0
# Mthly_HH_Expense   17000.0
# No_of_Fly_Members   4.0
# Emi_or_Rent_Amt   0.0
# Annual_HH_Income   453120.0
# Highest_Qualified_Member   2.0
# No_of_Earning_Members   1.0

# %%
plt.figure(figsize=(10, 10))
plt.title(f"Annual_HH_Income Level Distribution")
sns.histplot(df['Annual_HH_Income'], stat='density', color='grey')
sns.kdeplot(df['Annual_HH_Income'], color='red')
plt.axvline(df['Annual_HH_Income'].median(), color='blue',linestyle="--")
plt.show()

# %% [markdown]
# ### Mode:- A mode is defined as the value that has a higher frequency in a given set of values. It is the value that appears the most number of times.

# %% [markdown]
# ### Mathematical formula:-
# $$ L + \frac{(f_{m}-f_{1})\times h}{(f_{m}-f_{1})+(f_{m}-f_{2})}$$

# %%
df.mode()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0          45000.0           25000.0                4.0              0.0
#
#    Annual_HH_Income  Highest_Qualified_Member  No_of_Earning_Members
# 0          590400.0                       0.0                    1.0

# %% [markdown]
# ### Variance:-Variance measures how far a data set is spread out. It is mathematically defined as the average of the squared differences from the mean.

# %% [markdown]
# ### Mathematical Formula:-
# population Variance  $$ \sigma^2=\sum_{i=0}^n\frac{(x_{i}-\mu )^2}{N} $$
# Sample Variance      $$ \sigma^2=\sum_{i=0}^n\frac{(x_{i}-\bar{x})^2}{N} $$

# %%
#using library
print(np.var(list(df['Mthly_HH_Expense'])))
print(np.var(list(df['Annual_HH_Income'])))
# Out:
# 143249876.0
# 100437186889.9584

# %%
for name in df.columns:
    l = list(df[name])
    sum=0
    for i in l:
        sum+=i
    avg =  sum/ len(l)
    sum1=0
    for i in l:
        sum1+=(i-avg)**2
    var = sum1 / len(l)
    print(f"{name}------------{var}")
# Out:
# Mthly_HH_Income------------667478836.0
# Mthly_HH_Expense------------143249876.0
# No_of_Fly_Members------------2.2564
# Emi_or_Rent_Amt------------38176400.0
# Annual_HH_Income------------100437186889.95831
# Highest_Qualified_Member------------2.5524000000000004
# No_of_Earning_Members------------0.5284

# %% [markdown]
# ### Standard deviation:-Standard deviation is a measure of dispersement in statistics. “Dispersement” tells you how much your data is spread out. Specifically, it shows you how much your data is spread out around the mean or average.

# %% [markdown]
# ### Mathematical Formula:-
# Population Standard Deviation $$ \sigma = \sqrt \frac{\sum_{i=0}^n(x_{i}-\mu)^2}{N} $$
# Sample Standard Deviation $$ \sigma= \sqrt \frac{\sum_{i=0}^n(x_{i}-\bar{x})^2}{n-1} $$

# %%
df.std()
# Out:
# Mthly_HH_Income              26097.908979
# Mthly_HH_Expense             12090.216824
# No_of_Fly_Members                1.517382
# Emi_or_Rent_Amt               6241.434948
# Annual_HH_Income            320135.792123
# Highest_Qualified_Member         1.613843
# No_of_Earning_Members            0.734291
# dtype: float64

# %%
for name in df.columns:
    l = list(df[name])
    sum=0
    for i in l:
        sum+=i
    avg =  sum/ len(l)
    sum1=0
    for i in l:
        sum1+=(i-avg)**2
    var = sum1 / len(l)
    std = math.sqrt(var)
    print(f"{name}------------{std}")
# Out:
# Mthly_HH_Income------------25835.611779092826
# Mthly_HH_Expense------------11968.704023410388
# No_of_Fly_Members------------1.502131818450032
# Emi_or_Rent_Amt------------6178.705366013175
# Annual_HH_Income------------316918.26531451027
# Highest_Qualified_Member------------1.597623234683322
# No_of_Earning_Members------------0.72691127381545

# %% [markdown]
# ### Defintion-Correlation is a statistical measure that expresses the extent to which two variables are linearly related (meaning they change together at a constant rate). It’s a common tool for describing simple relationships without making a statement about cause and effect.

# %%
df.corr()
# Out:
#                           Mthly_HH_Income  Mthly_HH_Expense  \
# Mthly_HH_Income                  1.000000          0.649215
# Mthly_HH_Expense                 0.649215          1.000000
# No_of_Fly_Members                0.448317          0.639702
# Emi_or_Rent_Amt                  0.036976          0.405280
# Annual_HH_Income                 0.970315          0.591222
# Highest_Qualified_Member        -0.013880         -0.019001
# No_of_Earning_Members            0.347883          0.311915
#
#                           No_of_Fly_Members  Emi_or_Rent_Amt  \
# Mthly_HH_Income                    0.448317         0.036976
# Mthly_HH_Expense                   0.639702         0.405280
# No_of_Fly_Members                  1.000000         0.085808
# Emi_or_Rent_Amt                    0.085808         1.000000
# Annual_HH_Income                   0.430868         0.002716
# Highest_Qualified_Member           0.056504        -0.013615
# No_of_Earning_Members              0.597482        -0.097431
#
#                           Annual_HH_Income  Highest_Qualified_Member  \
# Mthly_HH_Income                   0.970315                 -0.013880
# Mthly_HH_Expense                  0.591222                 -0.019001
# No_of_Fly_Members                 0.430868                  0.056504
# Emi_or_Rent_Amt                   0.002716                 -0.013615
# Annual_HH_Income                  1.000000                 -0.030077
# Highest_Qualified_Member         -0.030077                  1.000000
# No_of_Earning_Members             0.296679                  0.154650
#
#                           No_of_Earning_Members
# Mthly_HH_Income                        0.347883
# Mthly_HH_Expense                       0.311915
# No_of_Fly_Members                      0.597482
# Emi_or_Rent_Amt                       -0.097431
# Annual_HH_Income                       0.296679
# Highest_Qualified_Member               0.154650
# No_of_Earning_Members                  1.000000

# %%
plt.figure(figsize=(10,10))
cmap=sns.diverging_palette(230,20,as_cmap=True)
sns.heatmap(df.corr(),annot=True,cmap=cmap)
plt.show()

# %% [markdown]
# ## The Normal Distribution
# ### Normal distribution, also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean. In graph form, normal distribution will appear as a bell curve.The graph of the normal distribution is characterized by two parameters: the mean, or average, which is the maximum of the graph and about which the graph is always symmetric; and the standard deviation, which determines the amount of dispersion away from the mean. A small standard deviation (compared with the mean) produces a steep graph, whereas a large standard deviation (again compared with the mean) produces a flat graph.

# %% [markdown]
# #### For a normal distribution, 68% of the observations are within +/- one standard deviation of the mean, 95% are within +/- two standard deviations, and 99.7% are within +- three standard deviations.

# %% [markdown]
# ### Mathematical Formula:- $$\frac1{\sqrt{2\pi\sigma^2}}{exp}^\frac{x-\mu}{\sigma}$$

# %% [markdown]
# ### Positively Skewed Normal Distribution:
#
# #### In statistics, a positively skewed (or right-skewed) distribution is a type of distribution in which most values are clustered around the left tail of the distribution while the right tail of the distribution is longer. The positively skewed distribution is a direct opposite of the negatively skewed distribution.
# #### Effect on Mean, Median and Mode due to Positive Skewness: Mean> Median> Mode

# %% [markdown]
# ### Negatively Skewed Normal Distribution:
#
# #### In statistics, a negatively skewed (also known as left-skewed) distribution is a type of distribution in which more values are concentrated on the right side (tail) of the distribution graph while the left tail of the distribution graph is longer.

# %% [markdown]
# ### Formula:
# #### 1.Mode Skewness:

# %% [markdown]
#  $$Skew =\frac{mean-mode}{Std.dev}$$

# %% [markdown]
# #### 2.Median Skewness::

# %% [markdown]
# $$ skew = \frac{(mean-median)}{Std.Dev}$$

# %%
plt.figure(figsize=(10, 10))
plt.title(f"Annual_HH_Income Level Distribution- positively skewed")
sns.histplot(df['Annual_HH_Income'], stat='density', color='grey')
sns.kdeplot(df['Annual_HH_Income'], color='red')
plt.show()

# %% [markdown]
# ## Q-Q(quantile-quantile) Plot
# ### In Statistics, Q-Q(quantile-quantile) plots play a very vital role to graphically analyze and compare two probability distributions by plotting their quantiles against each other. If the two distributions which we are comparing are exactly equal then the points on the Q-Q plot will perfectly lie on a straight line y = x.Q-Q plots are used to find the type of distribution for a random variable whether it be a Gaussian Distribution, Uniform Distribution, Exponential Distribution or even Pareto Distribution, etc. We can tell the type of distribution using the power of the Q-Q plot just by looking at the plot.

# %%
import statsmodels.api as sm
import pylab as py
data = df['Annual_HH_Income']
sm.qqplot(data, line ='45')
